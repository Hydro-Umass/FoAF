# %%
import pandas as pd

# %%
hist_data = pd.read_csv("hydro_hist.csv")

# %%
prefix_to_match = "NE"
NE_hist_data = hist_data[hist_data["PU_CODE"].str.startswith(prefix_to_match)]
NE_hist_data
# Out:
#          OBJECTID    COMID               GNIS_NAME  LENGTHKM  FTYPE PU_CODE  \
# 1893467   1893468  2680086             Tunk Stream     0.597    460    NE01
# 1893468   1893469  2680084             Tunk Stream     1.042    460    NE01
# 1893469   1893470  2677318  Whitten Parritt Stream     1.420    460    NE01
# 1893470   1893471  2691996  Whitten Parritt Stream     0.247    334    NE01
# 1906743   1906744  1721757     Eighteen Pond Brook     1.121    460    NE01
# ...           ...      ...                     ...       ...    ...     ...
# 2061263   2061264  2676978             Bells Brook     0.669    460    NE01
# 2061264   2061265  2676950             Bells Brook     2.835    460    NE01
# 2061265   2061266  2674052            Allen Stream     3.948    460    NE01
# 2061266   2061267  2679238        Alligator Stream     1.200    460    NE01
# 2061267   2061268  2680674        Alligator Stream     8.722    460    NE01
#
# ...

# %%
mid_data = pd.read_csv("hydro_mid.csv")
NE_mid_data = mid_data[mid_data["PU_CODE"].str.startswith(prefix_to_match)]
NE_mid_data
# Out:
#          OBJECTID     COMID        GNIS_NAME  LENGTHKM  FTYPE PU_CODE  \
# 1875294   1875295   2675360                      1.911    558    NE01
# 1875295   1875296   2674872                      1.806    460    NE01
# 1921219   1921220   7733097  Greenwich Creek     0.098    460    NE01
# 1921220   1921221  25077348  Greenwich Creek     0.646    558    NE01
# 1921221   1921222  25077346  Greenwich Creek     0.535    558    NE01
# ...           ...       ...              ...       ...    ...     ...
# 2048141   2048142   6125331     Queset Brook     1.177    460    NE01
# 2048142   2048143   6125803     Queset Brook     1.241    558    NE01
# 2048143   2048144   6125787     Queset Brook     0.012    558    NE01
# 2048144   2048145   6125279     Queset Brook     1.980    460    NE01
# 2048145   2048146   6125785     Queset Brook     0.337    558    NE01
#
#          TOTDASQKM  TIDAL WBAREATYPE    MA_2040  ...  HIQ1_5_2040  HIQ10_2040  \
# ...

# %%
late_data = pd.read_csv("hydro_late.csv")
NE_late_data = late_data[late_data["PU_CODE"].str.startswith(prefix_to_match)]
NE_late_data
# Out:
#          OBJECTID    COMID      GNIS_NAME  LENGTHKM  FTYPE PU_CODE  TOTDASQKM  \
# 1850560   1850561  6712013                    0.558    460    NE01   384.8499
# 1850561   1850562  6712041                    1.025    460    NE01   122.9562
# 1850562   1850563  6712145   Potash Brook     3.965    460    NE01     6.5880
# 1850922   1850923  6711985     Dead River     4.771    460    NE01    25.9038
# 1850923   1850924  6711997   Webber Brook     5.933    460    NE01     7.3764
# ...           ...      ...            ...       ...    ...     ...        ...
# 2165550   2165551  9315803                    2.318    460    NE01     2.1582
# 2165551   2165552  9315815                    1.608    460    NE01     2.7765
# 2165552   2165553  9315891  Moulton Brook     2.312    460    NE01     1.9215
# 2165553   2165554  9315937  Bennett Brook     3.689    460    NE01     4.8159
# 2165554   2165555  9312941                    1.389    460    NE01     5.3046
#
# ...

# %%
mid_abs_change = pd.read_csv("abs_change_mid.csv")
NE_mid_abs_change = mid_abs_change[mid_abs_change["PU_CODE"].str.startswith(prefix_to_match)]
NE_mid_abs_change
# Out:
#          OBJECTID    COMID          GNIS_NAME  LENGTHKM  FTYPE PU_CODE  \
# 1703377   1703378  7690385         Coys Brook     2.622    460    NE01
# 1703378   1703379  7691657         Dunn Brook     1.030    460    NE01
# 1703379   1703380  7692073         Dunn Brook     0.118    558    NE01
# 1703380   1703381  7690517         Dunn Brook     0.316    460    NE01
# 1703381   1703382  7691627         Dunn Brook     1.889    460    NE01
# ...           ...      ...                ...       ...    ...     ...
# 2190967   2190968  1720983  Big Wilson Stream     0.320    460    NE01
# 2190968   2190969  1720985  Big Wilson Stream     2.141    460    NE01
# 2190969   2190970  1720953  Big Wilson Stream     0.506    460    NE01
# 2190970   2190971  1720933  Big Wilson Stream     2.088    460    NE01
# 2190971   2190972  1722831       Leeman Brook     3.995    460    NE01
#
#          TOTDASQKM  TIDAL   WBAREATYPE  MA_A2040  ...  HIQ1_5_A2040  \
# ...

# %%
late_abs_change = pd.read_csv("abs_change_late.csv")
NE_late_abs_change = late_abs_change[late_abs_change["PU_CODE"].str.startswith(prefix_to_match)]
NE_late_abs_change
# Out:
#          OBJECTID    COMID           GNIS_NAME  LENGTHKM  FTYPE PU_CODE  \
# 1907742   1907743  6740528         Turee Brook     1.463    460    NE01
# 1907743   1907744  6740584                         2.882    460    NE01
# 1907744   1907745  6741450         White Brook     1.729    460    NE01
# 1907745   1907746  6740554                         2.337    460    NE01
# 1907746   1907747  6090207                         2.916    460    NE01
# ...           ...      ...                 ...       ...    ...     ...
# 2047424   2047425  5849494                         1.524    558    NE01
# 2047425   2047426  5849250                         0.929    460    NE01
# 2047426   2047427  6763298  North Branch River     0.844    460    NE01
# 2047427   2047428  6763334        Bailey Brook     0.231    460    NE01
# 2047428   2047429  6763340        Bailey Brook     0.313    460    NE01
#
#          TOTDASQKM  TIDAL   WBAREATYPE   MA_A2080  ...  HIQ1_5_A2080  \
# ...

# %%
mid_prc_change = pd.read_csv("mid_prc_change.csv")
NE_mid_prc_change = mid_prc_change[mid_prc_change["PU_CODE"].str.startswith(prefix_to_match)]
NE_mid_prc_change
# Out:
#          OBJECTID    COMID                   GNIS_NAME  LENGTHKM  FTYPE  \
# 1928171   1928172   804611  South Branch Machias River     3.650    460
# 1928172   1928173   804617  South Branch Machias River     4.500    460
# 1928173   1928174   804633  South Branch Machias River     5.134    460
# 1928174   1928175   805315             Aroostook River     1.615    558
# 1928175   1928176   811533             Aroostook River     0.848    558
# ...           ...      ...                         ...       ...    ...
# 2027432   2027433  9343905               Millers River     0.016    558
# 2027433   2027434  9343473               Millers River     1.326    460
# 2027434   2027435  9343495               Millers River     0.663    460
# 2027435   2027436  7716636           Beacon Hill Brook     1.097    460
# 2027436   2027437  7714882                                 0.179    460
#
#         PU_CODE  TOTDASQKM  TIDAL   WBAREATYPE  MA_P2040  ...  MJJA_P2040  \
# ...

# %%
late_prc_change = pd.read_csv("late_prc_change.csv")
NE_late_prc_change = late_prc_change[late_prc_change["PU_CODE"].str.startswith(prefix_to_match)]
NE_late_prc_change
# Out:
#          OBJECTID    COMID                 GNIS_NAME  LENGTHKM  FTYPE PU_CODE  \
# 1531614   1531615   803635  West Branch Salmon Brook     1.657    460    NE01
# 1531615   1531616   804813  West Branch Salmon Brook     5.195    460    NE01
# 1531616   1531617   803663                               3.704    460    NE01
# 1708971   1708972   804815                               2.849    460    NE01
# 1708972   1708973   803609                               0.357    460    NE01
# ...           ...      ...                       ...       ...    ...     ...
# 2156355   2156356  7711918                               0.112    460    NE01
# 2156356   2156357  7711922                               0.237    460    NE01
# 2156357   2156358  7711912                               0.667    460    NE01
# 2156358   2156359  7713458         Wangum Lake Brook     2.520    460    NE01
# 2156359   2156360  7713460         Wangum Lake Brook     0.443    460    NE01
#
# ...
